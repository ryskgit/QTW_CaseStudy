# %%
import requests
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
from dython.nominal import identify_nominal_columns
from dython.nominal import associations
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score, train_test_split, cross_validate
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

# %%
diabetes = pd.read_csv('dataset_diabetes/diabetic_data.csv')

# %%
pd.set_option('display.max_columns', None)

# %%
diabetes.head(20)
# Out:
#     encounter_id  patient_nbr             race  gender       age weight  \
# 0        2278392      8222157        Caucasian  Female    [0-10)      ?
# 1         149190     55629189        Caucasian  Female   [10-20)      ?
# 2          64410     86047875  AfricanAmerican  Female   [20-30)      ?
# 3         500364     82442376        Caucasian    Male   [30-40)      ?
# 4          16680     42519267        Caucasian    Male   [40-50)      ?
# 5          35754     82637451        Caucasian    Male   [50-60)      ?
# 6          55842     84259809        Caucasian    Male   [60-70)      ?
# 7          63768    114882984        Caucasian    Male   [70-80)      ?
# 8          12522     48330783        Caucasian  Female   [80-90)      ?
# 9          15738     63555939        Caucasian  Female  [90-100)      ?
# 10         28236     89869032  AfricanAmerican  Female   [40-50)      ?
# 11         36900     77391171  AfricanAmerican    Male   [60-70)      ?
# 12         40926     85504905        Caucasian  Female   [40-50)      ?
# 13         42570     77586282        Caucasian    Male   [80-90)      ?
# 14         62256     49726791  AfricanAmerican  Female   [60-70)      ?
# 15         73578     86328819  AfricanAmerican    Male   [60-70)      ?
# 16         77076     92519352  AfricanAmerican    Male   [50-60)      ?
# 17         84222    108662661        Caucasian  Female   [50-60)      ?
# 18         89682    107389323  AfricanAmerican    Male   [70-80)      ?
# 19        148530     69422211                ?    Male   [70-80)      ?
#
#     admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                   6                        25                    1
# 1                   1                         1                    7
# 2                   1                         1                    7
# 3                   1                         1                    7
# 4                   1                         1                    7
# 5                   2                         1                    2
# 6                   3                         1                    2
# 7                   1                         1                    7
# 8                   2                         1                    4
# 9                   3                         3                    4
# 10                  1                         1                    7
# 11                  2                         1                    4
# 12                  1                         3                    7
# 13                  1                         6                    7
# 14                  3                         1                    2
# 15                  1                         3                    7
# 16                  1                         1                    7
# 17                  1                         1                    7
# 18                  1                         1                    7
# 19                  3                         6                    2
#
#     time_in_hospital payer_code         medical_specialty  num_lab_procedures  \
# 0                  1          ?  Pediatrics-Endocrinology                  41
# 1                  3          ?                         ?                  59
# 2                  2          ?                         ?                  11
# 3                  2          ?                         ?                  44
# 4                  1          ?                         ?                  51
# 5                  3          ?                         ?                  31
# 6                  4          ?                         ?                  70
# 7                  5          ?                         ?                  73
# 8                 13          ?                         ?                  68
# 9                 12          ?          InternalMedicine                  33
# 10                 9          ?                         ?                  47
# 11                 7          ?                         ?                  62
# 12                 7          ?    Family/GeneralPractice                  60
# 13                10          ?    Family/GeneralPractice                  55
# 14                 1          ?                         ?                  49
# 15                12          ?                         ?                  75
# 16                 4          ?                         ?                  45
# 17                 3          ?                Cardiology                  29
# 18                 5          ?                         ?                  35
# 19                 6          ?                         ?                  42
#
#     num_procedures  num_medications  number_outpatient  number_emergency  \
# 0                0                1                  0                 0
# 1                0               18                  0                 0
# 2                5               13                  2                 0
# 3                1               16                  0                 0
# 4                0                8                  0                 0
# 5                6               16                  0                 0
# 6                1               21                  0                 0
# 7                0               12                  0                 0
# 8                2               28                  0                 0
# 9                3               18                  0                 0
# 10               2               17                  0                 0
# 11               0               11                  0                 0
# 12               0               15                  0                 1
# 13               1               31                  0                 0
# 14               5                2                  0                 0
# 15               5               13                  0                 0
# 16               4               17                  0                 0
# 17               0               11                  0                 0
# 18               5               23                  0                 0
# 19               2               23                  0                 0
#
#     number_inpatient  diag_1  diag_2 diag_3  number_diagnoses max_glu_serum  \
# 0                  0  250.83       ?      ?                 1          None
# 1                  0     276  250.01    255                 9          None
# 2                  1     648     250    V27                 6          None
# 3                  0       8  250.43    403                 7          None
# 4                  0     197     157    250                 5          None
# 5                  0     414     411    250                 9          None
# 6                  0     414     411    V45                 7          None
# 7                  0     428     492    250                 8          None
# 8                  0     398     427     38                 8          None
# 9                  0     434     198    486                 8          None
# 10                 0   250.7     403    996                 9          None
# 11                 0     157     288    197                 7          None
# 12                 0     428  250.43  250.6                 8          None
# 13                 0     428     411    427                 8          None
# 14                 0     518     998    627                 8          None
# 15                 0     999     507    996                 9          None
# 16                 0     410     411    414                 8          None
# 17                 0     682     174    250                 3          None
# 18                 0     402     425    416                 9          None
# 19                 0     737     427    714                 8          None
#
#    A1Cresult metformin repaglinide nateglinide chlorpropamide glimepiride  \
# 0       None        No          No          No             No          No
# 1       None        No          No          No             No          No
# 2       None        No          No          No             No          No
# 3       None        No          No          No             No          No
# 4       None        No          No          No             No          No
# 5       None        No          No          No             No          No
# 6       None    Steady          No          No             No      Steady
# 7       None        No          No          No             No          No
# 8       None        No          No          No             No          No
# 9       None        No          No          No             No          No
# 10      None        No          No          No             No          No
# 11      None        No          No          No             No          No
# 12      None    Steady          Up          No             No          No
# 13      None        No          No          No             No          No
# 14      None        No          No          No             No          No
# 15      None        No          No          No             No          No
# 16      None        No          No          No             No          No
# 17      None        No          No          No             No          No
# 18      None        No          No          No             No          No
# 19      None        No          No          No             No          No
#
#    acetohexamide glipizide glyburide tolbutamide pioglitazone rosiglitazone  \
# 0             No        No        No          No           No            No
# 1             No        No        No          No           No            No
# 2             No    Steady        No          No           No            No
# 3             No        No        No          No           No            No
# 4             No    Steady        No          No           No            No
# 5             No        No        No          No           No            No
# 6             No        No        No          No           No            No
# 7             No        No    Steady          No           No            No
# 8             No    Steady        No          No           No            No
# 9             No        No        No          No           No        Steady
# 10            No        No        No          No           No            No
# 11            No        No        Up          No           No            No
# 12            No        No        No          No           No            No
# 13            No        No        No          No           No            No
# 14            No        No        No          No           No            No
# 15            No        No        No          No           No            No
# 16            No    Steady        No          No           No            No
# 17            No        No    Steady          No           No            No
# 18            No        No        No          No           No            No
# 19            No        No      Down          No           No            No
#
#    acarbose miglitol troglitazone tolazamide examide citoglipton insulin  \
# 0        No       No           No         No      No          No      No
# 1        No       No           No         No      No          No      Up
# 2        No       No           No         No      No          No      No
# 3        No       No           No         No      No          No      Up
# 4        No       No           No         No      No          No  Steady
# 5        No       No           No         No      No          No  Steady
# 6        No       No           No         No      No          No  Steady
# 7        No       No           No         No      No          No      No
# 8        No       No           No         No      No          No  Steady
# 9        No       No           No         No      No          No  Steady
# 10       No       No           No         No      No          No  Steady
# 11       No       No           No         No      No          No  Steady
# 12       No       No           No         No      No          No    Down
# 13       No       No           No         No      No          No  Steady
# 14       No       No           No         No      No          No  Steady
# 15       No       No           No         No      No          No      Up
# 16       No       No           No         No      No          No  Steady
# 17       No       No           No         No      No          No      No
# 18       No       No           No         No      No          No  Steady
# 19       No       No           No         No      No          No  Steady
#
#    glyburide-metformin glipizide-metformin glimepiride-pioglitazone  \
# 0                   No                  No                       No
# 1                   No                  No                       No
# 2                   No                  No                       No
# 3                   No                  No                       No
# 4                   No                  No                       No
# 5                   No                  No                       No
# 6                   No                  No                       No
# 7                   No                  No                       No
# 8                   No                  No                       No
# 9                   No                  No                       No
# 10                  No                  No                       No
# 11                  No                  No                       No
# 12                  No                  No                       No
# 13                  No                  No                       No
# 14                  No                  No                       No
# 15                  No                  No                       No
# 16                  No                  No                       No
# 17                  No                  No                       No
# 18                  No                  No                       No
# 19                  No                  No                       No
#
#    metformin-rosiglitazone metformin-pioglitazone change diabetesMed  \
# 0                       No                     No     No          No
# 1                       No                     No     Ch         Yes
# 2                       No                     No     No         Yes
# 3                       No                     No     Ch         Yes
# 4                       No                     No     Ch         Yes
# 5                       No                     No     No         Yes
# 6                       No                     No     Ch         Yes
# 7                       No                     No     No         Yes
# 8                       No                     No     Ch         Yes
# 9                       No                     No     Ch         Yes
# 10                      No                     No     No         Yes
# 11                      No                     No     Ch         Yes
# 12                      No                     No     Ch         Yes
# 13                      No                     No     No         Yes
# 14                      No                     No     No         Yes
# 15                      No                     No     Ch         Yes
# 16                      No                     No     Ch         Yes
# 17                      No                     No     No         Yes
# 18                      No                     No     No         Yes
# 19                      No                     No     Ch         Yes
#
#    readmitted
# 0          NO
# 1         >30
# 2          NO
# 3          NO
# 4          NO
# 5         >30
# 6          NO
# 7         >30
# 8          NO
# 9          NO
# 10        >30
# 11        <30
# 12        <30
# 13         NO
# 14        >30
# 15         NO
# 16        <30
# 17         NO
# 18        >30
# 19         NO

# %%
pd.reset_option("max_columns")

# %%
diabetes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101766 entries, 0 to 101765
# Data columns (total 50 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   encounter_id              101766 non-null  int64
#  1   patient_nbr               101766 non-null  int64
#  2   race                      101766 non-null  object
#  3   gender                    101766 non-null  object
#  4   age                       101766 non-null  object
#  5   weight                    101766 non-null  object
#  6   admission_type_id         101766 non-null  int64
#  7   discharge_disposition_id  101766 non-null  int64
#  8   admission_source_id       101766 non-null  int64
#  9   time_in_hospital          101766 non-null  int64
#  10  payer_code                101766 non-null  object
#  11  medical_specialty         101766 non-null  object
#  12  num_lab_procedures        101766 non-null  int64
#  13  num_procedures            101766 non-null  int64
#  14  num_medications           101766 non-null  int64
#  15  number_outpatient         101766 non-null  int64
#  16  number_emergency          101766 non-null  int64
#  17  number_inpatient          101766 non-null  int64
#  18  diag_1                    101766 non-null  object
#  19  diag_2                    101766 non-null  object
#  20  diag_3                    101766 non-null  object
#  21  number_diagnoses          101766 non-null  int64
#  22  max_glu_serum             101766 non-null  object
#  23  A1Cresult                 101766 non-null  object
#  24  metformin                 101766 non-null  object
#  25  repaglinide               101766 non-null  object
#  26  nateglinide               101766 non-null  object
#  27  chlorpropamide            101766 non-null  object
#  28  glimepiride               101766 non-null  object
#  29  acetohexamide             101766 non-null  object
#  30  glipizide                 101766 non-null  object
#  31  glyburide                 101766 non-null  object
#  32  tolbutamide               101766 non-null  object
#  33  pioglitazone              101766 non-null  object
#  34  rosiglitazone             101766 non-null  object
#  35  acarbose                  101766 non-null  object
#  36  miglitol                  101766 non-null  object
#  37  troglitazone              101766 non-null  object
#  38  tolazamide                101766 non-null  object
#  39  examide                   101766 non-null  object
#  40  citoglipton               101766 non-null  object
#  41  insulin                   101766 non-null  object
#  42  glyburide-metformin       101766 non-null  object
#  43  glipizide-metformin       101766 non-null  object
#  44  glimepiride-pioglitazone  101766 non-null  object
#  45  metformin-rosiglitazone   101766 non-null  object
#  46  metformin-pioglitazone    101766 non-null  object
#  47  change                    101766 non-null  object
#  48  diabetesMed               101766 non-null  object
#  49  readmitted                101766 non-null  object
# dtypes: int64(13), object(37)
# memory usage: 38.8+ MB

# %%
def range(column):
    mean = column.mean()
    min = column.min()
    max = column.max()
    print(f'Mean : {mean}')
    print(f'Min : {min}')
    print(f'Max : {max}')

# %%
print(f'Simple Summary Statistics for Numeric Columns')
for i in diabetes.columns:
    if diabetes[i].dtypes == 'int64':
        print(f'{i}')
        range(diabetes[i])
        print('------------')
# Out:
# Simple Summary Statistics for Numeric Columns
# encounter_id
# Mean : 165201645.6229782
# Min : 12522
# Max : 443867222
# ------------
# patient_nbr
# Mean : 54330400.694947235
# Min : 135
# Max : 189502619
# ------------
# admission_type_id
# Mean : 2.024006053102215
# Min : 1
# Max : 8
# ------------
# discharge_disposition_id
# Mean : 3.7156417664052825
# Min : 1
# Max : 28
# ------------
# admission_source_id
# Mean : 5.754436648782501
# Min : 1
# Max : 25
# ------------
# time_in_hospital
# Mean : 4.395986871843248
# Min : 1
# Max : 14
# ------------
# num_lab_procedures
# Mean : 43.09564098028811
# Min : 1
# Max : 132
# ------------
# num_procedures
# Mean : 1.339730361810428
# Min : 0
# Max : 6
# ------------
# num_medications
# Mean : 16.021844230882614
# Min : 1
# Max : 81
# ------------
# number_outpatient
# Mean : 0.36935715268360747
# Min : 0
# Max : 42
# ------------
# number_emergency
# Mean : 0.19783621248747127
# Min : 0
# Max : 76
# ------------
# number_inpatient
# Mean : 0.635565906098304
# Min : 0
# Max : 21
# ------------
# number_diagnoses
# Mean : 7.422606764538254
# Min : 1
# Max : 16
# ------------

# %% [markdown]
# in 'discharge_disposition', no instances with value of '29'
# in 'admission_source_id', no instance with value of '26'

# %%
diabetes.hist(bins=30, figsize=(20, 20))
# Out:
# array([[<AxesSubplot:title={'center':'encounter_id'}>,
#         <AxesSubplot:title={'center':'patient_nbr'}>,
#         <AxesSubplot:title={'center':'admission_type_id'}>,
#         <AxesSubplot:title={'center':'discharge_disposition_id'}>],
#        [<AxesSubplot:title={'center':'admission_source_id'}>,
#         <AxesSubplot:title={'center':'time_in_hospital'}>,
#         <AxesSubplot:title={'center':'num_lab_procedures'}>,
#         <AxesSubplot:title={'center':'num_procedures'}>],
#        [<AxesSubplot:title={'center':'num_medications'}>,
#         <AxesSubplot:title={'center':'number_outpatient'}>,
#         <AxesSubplot:title={'center':'number_emergency'}>,
#         <AxesSubplot:title={'center':'number_inpatient'}>],
#        [<AxesSubplot:title={'center':'number_diagnoses'}>,
#         <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %%
diabetes['race'].value_counts()
# Out:
# Caucasian          76099
# AfricanAmerican    19210
# ?                   2273
# Hispanic            2037
# Other               1506
# Asian                641
# Name: race, dtype: int64

# %%
diabetes['race'].dtypes
# Out:
# dtype('O')

# %%
for i in diabetes.columns:
    print(f'{i}')
    diabetes[i].dtypes
# Out:
# encounter_id
# patient_nbr
# race
# gender
# age
# weight
# admission_type_id
# discharge_disposition_id
# admission_source_id
# time_in_hospital
# payer_code
# medical_specialty
# num_lab_procedures
# num_procedures
# num_medications
# number_outpatient
# number_emergency
# number_inpatient
# diag_1
# diag_2
# diag_3
# number_diagnoses
# max_glu_serum
# A1Cresult
# metformin
# repaglinide
# nateglinide
# chlorpropamide
# glimepiride
# acetohexamide
# glipizide
# glyburide
# tolbutamide
# pioglitazone
# rosiglitazone
# acarbose
# miglitol
# troglitazone
# tolazamide
# examide
# citoglipton
# insulin
# glyburide-metformin
# glipizide-metformin
# glimepiride-pioglitazone
# metformin-rosiglitazone
# metformin-pioglitazone
# change
# diabetesMed
# readmitted

# %%
for i in diabetes.columns:
    if diabetes[i].dtypes == 'O':
        print(f'{i}')
        value = diabetes[i].value_counts()
        print(f'{value}')
        print('------------')
    else:
        pass
# Out:
# race
# Caucasian          76099
# AfricanAmerican    19210
# ?                   2273
# Hispanic            2037
# Other               1506
# Asian                641
# Name: race, dtype: int64
# ------------
# gender
# Female             54708
# Male               47055
# Unknown/Invalid        3
# Name: gender, dtype: int64
# ------------
# age
# [70-80)     26068
# [60-70)     22483
# [50-60)     17256
# [80-90)     17197
# [40-50)      9685
# [30-40)      3775
# [90-100)     2793
# [20-30)      1657
# [10-20)       691
# [0-10)        161
# Name: age, dtype: int64
# ------------
# weight
# ?            98569
# [75-100)      1336
# [50-75)        897
# [100-125)      625
# [125-150)      145
# [25-50)         97
# [0-25)          48
# [150-175)       35
# [175-200)       11
# >200             3
# Name: weight, dtype: int64
# ------------
# payer_code
# ?     40256
# MC    32439
# HM     6274
# SP     5007
# BC     4655
# MD     3532
# CP     2533
# UN     2448
# CM     1937
# OG     1033
# PO      592
# DM      549
# CH      146
# WC      135
# OT       95
# MP       79
# SI       55
# FR        1
# Name: payer_code, dtype: int64
# ------------
# medical_specialty
# ?                                49949
# InternalMedicine                 14635
# Emergency/Trauma                  7565
# Family/GeneralPractice            7440
# Cardiology                        5352
#                                  ...
# SportsMedicine                       1
# Speech                               1
# Perinatology                         1
# Neurophysiology                      1
# Pediatrics-InfectiousDiseases        1
# Name: medical_specialty, Length: 73, dtype: int64
# ------------
# diag_1
# 428    6862
# 414    6581
# 786    4016
# 410    3614
# 486    3508
#        ...
# 373       1
# 314       1
# 684       1
# 217       1
# V51       1
# Name: diag_1, Length: 717, dtype: int64
# ------------
# diag_2
# 276     6752
# 428     6662
# 250     6071
# 427     5036
# 401     3736
#         ...
# E918       1
# 46         1
# V13        1
# E850       1
# 927        1
# Name: diag_2, Length: 749, dtype: int64
# ------------
# diag_3
# 250     11555
# 401      8289
# 276      5175
# 428      4577
# 427      3955
#         ...
# 657         1
# 684         1
# 603         1
# E826        1
# 971         1
# Name: diag_3, Length: 790, dtype: int64
# ------------
# max_glu_serum
# None    96420
# Norm     2597
# >200     1485
# >300     1264
# Name: max_glu_serum, dtype: int64
# ------------
# A1Cresult
# None    84748
# >8       8216
# Norm     4990
# >7       3812
# Name: A1Cresult, dtype: int64
# ------------
# metformin
# No        81778
# Steady    18346
# Up         1067
# Down        575
# Name: metformin, dtype: int64
# ------------
# repaglinide
# No        100227
# Steady      1384
# Up           110
# Down          45
# Name: repaglinide, dtype: int64
# ------------
# nateglinide
# No        101063
# Steady       668
# Up            24
# Down          11
# Name: nateglinide, dtype: int64
# ------------
# chlorpropamide
# No        101680
# Steady        79
# Up             6
# Down           1
# Name: chlorpropamide, dtype: int64
# ------------
# glimepiride
# No        96575
# Steady     4670
# Up          327
# Down        194
# Name: glimepiride, dtype: int64
# ------------
# acetohexamide
# No        101765
# Steady         1
# Name: acetohexamide, dtype: int64
# ------------
# glipizide
# No        89080
# Steady    11356
# Up          770
# Down        560
# Name: glipizide, dtype: int64
# ------------
# glyburide
# No        91116
# Steady     9274
# Up          812
# Down        564
# Name: glyburide, dtype: int64
# ------------
# tolbutamide
# No        101743
# Steady        23
# Name: tolbutamide, dtype: int64
# ------------
# pioglitazone
# No        94438
# Steady     6976
# Up          234
# Down        118
# Name: pioglitazone, dtype: int64
# ------------
# rosiglitazone
# No        95401
# Steady     6100
# Up          178
# Down         87
# Name: rosiglitazone, dtype: int64
# ------------
# acarbose
# No        101458
# Steady       295
# Up            10
# Down           3
# Name: acarbose, dtype: int64
# ------------
# miglitol
# No        101728
# Steady        31
# Down           5
# Up             2
# Name: miglitol, dtype: int64
# ------------
# troglitazone
# No        101763
# Steady         3
# Name: troglitazone, dtype: int64
# ------------
# tolazamide
# No        101727
# Steady        38
# Up             1
# Name: tolazamide, dtype: int64
# ------------
# examide
# No    101766
# Name: examide, dtype: int64
# ------------
# citoglipton
# No    101766
# Name: citoglipton, dtype: int64
# ------------
# insulin
# No        47383
# Steady    30849
# Down      12218
# Up        11316
# Name: insulin, dtype: int64
# ------------
# glyburide-metformin
# No        101060
# Steady       692
# Up             8
# Down           6
# Name: glyburide-metformin, dtype: int64
# ------------
# glipizide-metformin
# No        101753
# Steady        13
# Name: glipizide-metformin, dtype: int64
# ------------
# glimepiride-pioglitazone
# No        101765
# Steady         1
# Name: glimepiride-pioglitazone, dtype: int64
# ------------
# metformin-rosiglitazone
# No        101764
# Steady         2
# Name: metformin-rosiglitazone, dtype: int64
# ------------
# metformin-pioglitazone
# No        101765
# Steady         1
# Name: metformin-pioglitazone, dtype: int64
# ------------
# change
# No    54755
# Ch    47011
# Name: change, dtype: int64
# ------------
# diabetesMed
# Yes    78363
# No     23403
# Name: diabetesMed, dtype: int64
# ------------
# readmitted
# NO     54864
# >30    35545
# <30    11357
# Name: readmitted, dtype: int64
# ------------

# %%
diabetes.dtypes
# Out:
# encounter_id                 int64
# patient_nbr                  int64
# race                        object
# gender                      object
# age                         object
# weight                      object
# admission_type_id            int64
# discharge_disposition_id     int64
# admission_source_id          int64
# time_in_hospital             int64
# payer_code                  object
# medical_specialty           object
# num_lab_procedures           int64
# num_procedures               int64
# num_medications              int64
# number_outpatient            int64
# number_emergency             int64
# number_inpatient             int64
# diag_1                      object
# diag_2                      object
# diag_3                      object
# number_diagnoses             int64
# max_glu_serum               object
# A1Cresult                   object
# metformin                   object
# repaglinide                 object
# nateglinide                 object
# chlorpropamide              object
# glimepiride                 object
# acetohexamide               object
# glipizide                   object
# glyburide                   object
# tolbutamide                 object
# pioglitazone                object
# rosiglitazone               object
# acarbose                    object
# miglitol                    object
# troglitazone                object
# tolazamide                  object
# examide                     object
# citoglipton                 object
# insulin                     object
# glyburide-metformin         object
# glipizide-metformin         object
# glimepiride-pioglitazone    object
# metformin-rosiglitazone     object
# metformin-pioglitazone      object
# change                      object
# diabetesMed                 object
# readmitted                  object
# dtype: object

# %%
cat = ['race', 'gender', ]

# %%
diabetes['race'].isnull()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 101761    False
# 101762    False
# 101763    False
# 101764    False
# 101765    False
# Name: race, Length: 101766, dtype: bool

# %%
diabetes.isna().sum()
# Out:
# encounter_id                0
# patient_nbr                 0
# race                        0
# gender                      0
# age                         0
# weight                      0
# admission_type_id           0
# discharge_disposition_id    0
# admission_source_id         0
# time_in_hospital            0
# payer_code                  0
# medical_specialty           0
# num_lab_procedures          0
# num_procedures              0
# num_medications             0
# number_outpatient           0
# number_emergency            0
# number_inpatient            0
# diag_1                      0
# diag_2                      0
# diag_3                      0
# number_diagnoses            0
# max_glu_serum               0
# A1Cresult                   0
# metformin                   0
# repaglinide                 0
# nateglinide                 0
# chlorpropamide              0
# glimepiride                 0
# acetohexamide               0
# glipizide                   0
# glyburide                   0
# tolbutamide                 0
# pioglitazone                0
# rosiglitazone               0
# acarbose                    0
# miglitol                    0
# troglitazone                0
# tolazamide                  0
# examide                     0
# citoglipton                 0
# insulin                     0
# glyburide-metformin         0
# glipizide-metformin         0
# glimepiride-pioglitazone    0
# metformin-rosiglitazone     0
# metformin-pioglitazone      0
# change                      0
# diabetesMed                 0
# readmitted                  0
# dtype: int64

# %%
# create copy to keep original dataset without manipulation
db_2 = diabetes.copy()

# %%
# missing values are displayed with a '?', so replace with Nan, which pandas can identify as a missing value
for i in db_2.columns:
    db_2[i].mask(db_2[i] == '?', np.nan, inplace=True)

# %%
# 7 columns with missing values
db_2.isna().sum()
# Out:
# encounter_id                    0
# patient_nbr                     0
# race                         2273
# gender                          0
# age                             0
# weight                      98569
# admission_type_id               0
# discharge_disposition_id        0
# admission_source_id             0
# time_in_hospital                0
# payer_code                  40256
# medical_specialty           49949
# num_lab_procedures              0
# num_procedures                  0
# num_medications                 0
# number_outpatient               0
# number_emergency                0
# number_inpatient                0
# diag_1                         21
# diag_2                        358
# diag_3                       1423
# number_diagnoses                0
# max_glu_serum                   0
# A1Cresult                       0
# metformin                       0
# repaglinide                     0
# nateglinide                     0
# chlorpropamide                  0
# glimepiride                     0
# acetohexamide                   0
# glipizide                       0
# glyburide                       0
# tolbutamide                     0
# pioglitazone                    0
# rosiglitazone                   0
# acarbose                        0
# miglitol                        0
# troglitazone                    0
# tolazamide                      0
# examide                         0
# citoglipton                     0
# insulin                         0
# glyburide-metformin             0
# glipizide-metformin             0
# glimepiride-pioglitazone        0
# metformin-rosiglitazone         0
# metformin-pioglitazone          0
# change                          0
# diabetesMed                     0
# readmitted                      0
# dtype: int64

# %%
# remove single value columns, no predictive value
single_vals = db_2.columns[db_2.eq(db_2.iloc[0]).all()].tolist()
print(f"There are {len(single_vals)} columns with single values: {single_vals}")
print(f"Original data dimiension: {db_2.shape}")
db_2.drop(columns=single_vals, inplace=True)
print(f"Final data dim after dropping aforementioned columns: {db_2.shape}")
print(f"There are {db_2.isna().sum().sum()} NA values and {db_2.duplicated().sum()} duplicated records")
# Out:
# There are 2 columns with single values: ['examide', 'citoglipton']
# Original data dimiension: (101766, 50)
# Final data dim after dropping aforementioned columns: (101766, 48)
# There are 192849 NA values and 0 duplicated records

# %%
# train/test split before imputing missing values

train, test = train_test_split(db_2, test_size=0.2, random_state=42)

# %%
# dimensions after 80/20 train/test split
print(f'Dimensions of train: {train.shape}')
print(f'Dimenstions of test: {test.shape}')
# Out:
# Dimensions of train: (81412, 48)
# Dimenstions of test: (20354, 48)

# %%
train['race'].isna().sum()
# Out:
# 1824

# %%
# specific columns with missing values
# a bit concerned about weight, payer_code, and medical_specialty given the amount of missing values. might not be worth imputing?
print(f'Columns with missing values:')
miss_val_col = []
for i in train.columns:
    val = train[i].isna().sum()
    if val > 0:
        print(f'{i} : {val}')
        miss_val_col.append(i)
# Out:
# Columns with missing values:
# race : 1824
# weight : 78852
# payer_code : 32135
# medical_specialty : 39969
# diag_1 : 17
# diag_2 : 271
# diag_3 : 1131

# %%
print(miss_val_col)
# Out:
# ['race', 'weight', 'payer_code', 'medical_specialty', 'diag_1', 'diag_2', 'diag_3']

# %%
# since all missing value columns are categorical, we can try imputing with the mode first
for i in miss_val_col:
    val = train[i].dtypes
    print(val)
# Out:
# object
# object
# object
# object
# object
# object
# object

# %%
train['medical_specialty'].mode()[0]
# Out:
# 'InternalMedicine'

# %%
# create copies of train,test to impute with mode of each var
test_mode = test.copy()
train_mode = train.copy()
for i in miss_val_col:
    train_mode[i] = train_mode[i].fillna(train_mode[i].mode()[0])
    test_mode[i] = test_mode[i].fillna(train_mode[i].mode()[0])

# %%
train_mode.isna().sum().sum()
# Out:
# 0

# %%
# Correlation Matrix
sns.set()
sns.set(style='darkgrid')
cmap = sns.diverging_palette(220, 10, as_cmap=True)
f, ax= plt.subplots(figsize=(10,10))

sns.heatmap(train.corr(),cmap=cmap,fmt='.3f',linewidth=.5,ax=ax)
f.tight_layout()

# %%
def cramers_v(x, y):
    confusion_matrix = pd.crosstab(x,y)
    chi2 = ss.chi2_contingency(confusion_matrix)[0]
    n = confusion_matrix.sum().sum()
    phi2 = chi2/n
    r,k = confusion_matrix.shape
    phi2corr = max(0, phi2-((k-1)*(r-1))/(n-1))
    rcorr = r-((r-1)**2)/(n-1)
    kcorr = k-((k-1)**2)/(n-1)
    return np.sqrt(phi2corr/min((kcorr-1),(rcorr-1)))

# %%
train_y = train['race']
train_x = train.drop(columns = 'race')

# %%
train.columns
# Out:
# Index(['encounter_id', 'patient_nbr', 'race', 'gender', 'age', 'weight',
#        'admission_type_id', 'discharge_disposition_id', 'admission_source_id',
#        'time_in_hospital', 'payer_code', 'medical_specialty',
#        'num_lab_procedures', 'num_procedures', 'num_medications',
#        'number_outpatient', 'number_emergency', 'number_inpatient', 'diag_1',
#        'diag_2', 'diag_3', 'number_diagnoses', 'max_glu_serum', 'A1Cresult',
#        'metformin', 'repaglinide', 'nateglinide', 'chlorpropamide',
#        'glimepiride', 'acetohexamide', 'glipizide', 'glyburide', 'tolbutamide',
#        'pioglitazone', 'rosiglitazone', 'acarbose', 'miglitol', 'troglitazone',
#        'tolazamide', 'insulin', 'glyburide-metformin', 'glipizide-metformin',
#        'glimepiride-pioglitazone', 'metformin-rosiglitazone',
#        'metformin-pioglitazone', 'change', 'diabetesMed', 'readmitted'],
#       dtype='object')

# %%
cat_features = identify_nominal_columns(train)
len(cat_features)
# Out:
# 35

# %%
complete_correlation= associations(train, figsize=(25,25))

# %%
df_complete_corr=complete_correlation['corr']
df_complete_corr.dropna(axis=1, how='all').dropna(axis=0, how='all').style.background_gradient(cmap='coolwarm', axis=None).set_precision(2)
# Out:
# /var/folders/8r/5z1j8hgs59d95j_4d6czqrf80000gn/T/ipykernel_1111/1661098780.py:2: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   df_complete_corr.dropna(axis=1, how='all').dropna(axis=0, how='all').style.background_gradient(cmap='coolwarm', axis=None).set_precision(2)
# <style type="text/css">
# #T_c57a9_row0_col0, #T_c57a9_row1_col1, #T_c57a9_row2_col2, #T_c57a9_row3_col3, #T_c57a9_row4_col4, #T_c57a9_row5_col5, #T_c57a9_row6_col6, #T_c57a9_row7_col7, #T_c57a9_row8_col8, #T_c57a9_row9_col9, #T_c57a9_row10_col10, #T_c57a9_row11_col11, #T_c57a9_row12_col12, #T_c57a9_row13_col13, #T_c57a9_row14_col14, #T_c57a9_row15_col15, #T_c57a9_row16_col16, #T_c57a9_row17_col17, #T_c57a9_row18_col18, #T_c57a9_row19_col19, #T_c57a9_row20_col20, #T_c57a9_row21_col21, #T_c57a9_row22_col22, #T_c57a9_row23_col23, #T_c57a9_row24_col24, #T_c57a9_row25_col25, #T_c57a9_row26_col26, #T_c57a9_row27_col27, #T_c57a9_row28_col28, #T_c57a9_row29_col29, #T_c57a9_row30_col30, #T_c57a9_row31_col31, #T_c57a9_row32_col32, #T_c57a9_row33_col33, #T_c57a9_row34_col34, #T_c57a9_row35_col35, #T_c57a9_row36_col36, #T_c57a9_row37_col37, #T_c57a9_row38_col38, #T_c57a9_row39_col39, #T_c57a9_row40_col40, #T_c57a9_row41_col41, #T_c57a9_row42_col42, #T_c57a9_row43_col43, #T_c57a9_row44_col44, #T_c57a9_row45_col45, #T_c57a9_row46_col46, #T_c57a9_row47_col47 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_c57a9_row0_col1, #T_c57a9_row1_col0 {
#   background-color: #efcfbf;
#   color: #000000;
# }
# #T_c57a9_row0_col2, #T_c57a9_row1_col15, #T_c57a9_row1_col22, #T_c57a9_row2_col0, #T_c57a9_row2_col19, #T_c57a9_row4_col23, #T_c57a9_row10_col19, #T_c57a9_row11_col45, #T_c57a9_row15_col1, #T_c57a9_row19_col2, #T_c57a9_row19_col10, #T_c57a9_row19_col46, #T_c57a9_row20_col24, #T_c57a9_row21_col39, #T_c57a9_row22_col1, #T_c57a9_row23_col4, #T_c57a9_row24_col20, #T_c57a9_row39_col21, #T_c57a9_row45_col11, #T_c57a9_row46_col19 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_c57a9_row0_col3, #T_c57a9_row0_col35, #T_c57a9_row0_col43, #T_c57a9_row0_col44, #T_c57a9_row1_col3, #T_c57a9_row1_col32, #T_c57a9_row1_col34, #T_c57a9_row1_col36, #T_c57a9_row2_col34, #T_c57a9_row2_col35, #T_c57a9_row3_col0, #T_c57a9_row3_col1, #T_c57a9_row3_col35, #T_c57a9_row3_col38, #T_c57a9_row3_col41, #T_c57a9_row4_col26, #T_c57a9_row4_col27, #T_c57a9_row5_col26, #T_c57a9_row5_col31, #T_c57a9_row6_col25, #T_c57a9_row6_col31, #T_c57a9_row6_col35, #T_c57a9_row6_col38, #T_c57a9_row6_col40, #T_c57a9_row6_col41, #T_c57a9_row7_col25, #T_c57a9_row7_col34, #T_c57a9_row7_col37, #T_c57a9_row7_col40, #T_c57a9_row7_col45, #T_c57a9_row8_col25, #T_c57a9_row8_col27, #T_c57a9_row8_col32, #T_c57a9_row8_col45, #T_c57a9_row9_col27, #T_c57a9_row9_col35, #T_c57a9_row9_col38, #T_c57a9_row9_col40, #T_c57a9_row10_col42, #T_c57a9_row12_col27, #T_c57a9_row12_col29, #T_c57a9_row12_col35, #T_c57a9_row12_col36, #T_c57a9_row12_col41, #T_c57a9_row13_col25, #T_c57a9_row13_col26, #T_c57a9_row13_col27, #T_c57a9_row13_col29, #T_c57a9_row13_col31, #T_c57a9_row13_col37, #T_c57a9_row13_col40, #T_c57a9_row13_col41, #T_c57a9_row13_col43, #T_c57a9_row13_col46, #T_c57a9_row14_col29, #T_c57a9_row14_col36, #T_c57a9_row14_col38, #T_c57a9_row14_col41, #T_c57a9_row15_col25, #T_c57a9_row15_col26, #T_c57a9_row15_col27, #T_c57a9_row15_col30, #T_c57a9_row15_col34, #T_c57a9_row15_col38, #T_c57a9_row16_col27, #T_c57a9_row16_col28, #T_c57a9_row16_col33, #T_c57a9_row16_col35, #T_c57a9_row17_col26, #T_c57a9_row17_col27, #T_c57a9_row17_col38, #T_c57a9_row21_col33, #T_c57a9_row21_col36, #T_c57a9_row21_col42, #T_c57a9_row21_col44, #T_c57a9_row22_col31, #T_c57a9_row23_col41, #T_c57a9_row23_col43, #T_c57a9_row24_col25, #T_c57a9_row24_col32, #T_c57a9_row25_col6, #T_c57a9_row25_col7, #T_c57a9_row25_col8, #T_c57a9_row25_col13, #T_c57a9_row25_col15, #T_c57a9_row25_col24, #T_c57a9_row25_col28, #T_c57a9_row25_col30, #T_c57a9_row25_col34, #T_c57a9_row26_col4, #T_c57a9_row26_col5, #T_c57a9_row26_col13, #T_c57a9_row26_col15, #T_c57a9_row26_col17, #T_c57a9_row26_col30, #T_c57a9_row26_col34, #T_c57a9_row26_col36, #T_c57a9_row26_col40, #T_c57a9_row27_col4, #T_c57a9_row27_col8, #T_c57a9_row27_col9, #T_c57a9_row27_col12, #T_c57a9_row27_col13, #T_c57a9_row27_col15, #T_c57a9_row27_col16, #T_c57a9_row27_col17, #T_c57a9_row27_col47, #T_c57a9_row28_col16, #T_c57a9_row28_col25, #T_c57a9_row28_col37, #T_c57a9_row28_col40, #T_c57a9_row28_col47, #T_c57a9_row29_col12, #T_c57a9_row29_col13, #T_c57a9_row29_col14, #T_c57a9_row30_col15, #T_c57a9_row30_col25, #T_c57a9_row30_col26, #T_c57a9_row31_col5, #T_c57a9_row31_col6, #T_c57a9_row31_col13, #T_c57a9_row31_col22, #T_c57a9_row32_col1, #T_c57a9_row32_col8, #T_c57a9_row32_col24, #T_c57a9_row32_col46, #T_c57a9_row33_col16, #T_c57a9_row33_col21, #T_c57a9_row33_col35, #T_c57a9_row33_col39, #T_c57a9_row34_col1, #T_c57a9_row34_col2, #T_c57a9_row34_col7, #T_c57a9_row34_col15, #T_c57a9_row34_col25, #T_c57a9_row34_col26, #T_c57a9_row35_col0, #T_c57a9_row35_col2, #T_c57a9_row35_col3, #T_c57a9_row35_col6, #T_c57a9_row35_col9, #T_c57a9_row35_col12, #T_c57a9_row35_col16, #T_c57a9_row35_col33, #T_c57a9_row35_col40, #T_c57a9_row36_col1, #T_c57a9_row36_col12, #T_c57a9_row36_col14, #T_c57a9_row36_col21, #T_c57a9_row36_col26, #T_c57a9_row36_col46, #T_c57a9_row36_col47, #T_c57a9_row37_col7, #T_c57a9_row37_col13, #T_c57a9_row37_col28, #T_c57a9_row38_col3, #T_c57a9_row38_col6, #T_c57a9_row38_col9, #T_c57a9_row38_col14, #T_c57a9_row38_col15, #T_c57a9_row38_col17, #T_c57a9_row38_col39, #T_c57a9_row39_col33, #T_c57a9_row39_col38, #T_c57a9_row40_col6, #T_c57a9_row40_col7, #T_c57a9_row40_col9, #T_c57a9_row40_col13, #T_c57a9_row40_col26, #T_c57a9_row40_col28, #T_c57a9_row40_col35, #T_c57a9_row41_col3, #T_c57a9_row41_col6, #T_c57a9_row41_col12, #T_c57a9_row41_col13, #T_c57a9_row41_col14, #T_c57a9_row41_col23, #T_c57a9_row41_col45, #T_c57a9_row41_col47, #T_c57a9_row42_col10, #T_c57a9_row42_col21, #T_c57a9_row43_col0, #T_c57a9_row43_col13, #T_c57a9_row43_col23, #T_c57a9_row44_col0, #T_c ...
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_c57a9_row0_col4, #T_c57a9_row2_col10, #T_c57a9_row4_col0, #T_c57a9_row10_col2, #T_c57a9_row10_col12, #T_c57a9_row12_col10, #T_c57a9_row18_col38, #T_c57a9_row20_col40, #T_c57a9_row20_col46, #T_c57a9_row38_col18, #T_c57a9_row40_col20, #T_c57a9_row46_col20 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_c57a9_row0_col5, #T_c57a9_row0_col17, #T_c57a9_row2_col9, #T_c57a9_row3_col9, #T_c57a9_row4_col5, #T_c57a9_row4_col25, #T_c57a9_row4_col33, #T_c57a9_row5_col0, #T_c57a9_row5_col4, #T_c57a9_row5_col9, #T_c57a9_row7_col28, #T_c57a9_row7_col46, #T_c57a9_row8_col39, #T_c57a9_row9_col2, #T_c57a9_row9_col3, #T_c57a9_row9_col5, #T_c57a9_row10_col28, #T_c57a9_row10_col33, #T_c57a9_row10_col41, #T_c57a9_row11_col30, #T_c57a9_row11_col40, #T_c57a9_row12_col33, #T_c57a9_row14_col23, #T_c57a9_row15_col23, #T_c57a9_row16_col31, #T_c57a9_row17_col0, #T_c57a9_row18_col28, #T_c57a9_row20_col34, #T_c57a9_row21_col31, #T_c57a9_row23_col14, #T_c57a9_row23_col15, #T_c57a9_row24_col28, #T_c57a9_row25_col4, #T_c57a9_row28_col7, #T_c57a9_row28_col10, #T_c57a9_row28_col18, #T_c57a9_row28_col24, #T_c57a9_row28_col34, #T_c57a9_row30_col11, #T_c57a9_row30_col33, #T_c57a9_row31_col16, #T_c57a9_row31_col21, #T_c57a9_row33_col4, #T_c57a9_row33_col10, #T_c57a9_row33_col12, #T_c57a9_row33_col30, #T_c57a9_row34_col20, #T_c57a9_row34_col28, #T_c57a9_row35_col46, #T_c57a9_row39_col8, #T_c57a9_row40_col11, #T_c57a9_row41_col10, #T_c57a9_row46_col7, #T_c57a9_row46_col35 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_c57a9_row0_col6, #T_c57a9_row6_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_c57a9_row0_col7, #T_c57a9_row7_col0 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_c57a9_row0_col8, #T_c57a9_row8_col0 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_c57a9_row0_col9, #T_c57a9_row9_col0, #T_c57a9_row13_col17, #T_c57a9_row17_col13 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_c57a9_row0_col10, #T_c57a9_row10_col0 {
#   background-color: #f4c6af;
#   color: #000000;
# }
# #T_c57a9_row0_col11, #T_c5

# %%
corr_df = complete_correlation['corr']

# %%
# correlation values for all columns with missing values. Unfortunately, correlations seem really low and unlikely to predict missing values accurately
for i in miss_val_col:
    print(f'{i.upper()}:')
    value = corr_df[i].nlargest(4, 'first')
    print(value[1:])
# Out:
# RACE:
# patient_nbr         0.161219
# number_diagnoses    0.115556
# diag_1              0.109262
# Name: race, dtype: float64
# WEIGHT:
# number_outpatient     0.104274
# num_lab_procedures    0.095610
# diag_2                0.080247
# Name: weight, dtype: float64
# PAYER_CODE:
# encounter_id         0.559445
# patient_nbr          0.306808
# admission_type_id    0.193105
# Name: payer_code, dtype: float64
# MEDICAL_SPECIALTY:
# encounter_id           0.373079
# patient_nbr            0.337775
# admission_source_id    0.296399
# Name: medical_specialty, dtype: float64
# DIAG_1:
# num_procedures      0.591346
# num_medications     0.390876
# time_in_hospital    0.385838
# Name: diag_1, dtype: float64
# DIAG_2:
# number_diagnoses            0.464289
# glimepiride-pioglitazone    0.366167
# num_procedures              0.362195
# Name: diag_2, dtype: float64
# DIAG_3:
# number_diagnoses    0.554655
# gender              0.386026
# time_in_hospital    0.326770
# Name: diag_3, dtype: float64

# %%
print(value.index[1:])
# Out:
# Index(['diag_3', 'number_diagnoses', 'gender', 'time_in_hospital'], dtype='object')

# %%
my_model = LogisticRegression()

# %%
train_x.columns
# Out:
# Index(['encounter_id', 'patient_nbr', 'gender', 'age', 'weight',
#        'admission_type_id', 'discharge_disposition_id', 'admission_source_id',
#        'time_in_hospital', 'payer_code', 'medical_specialty',
#        'num_lab_procedures', 'num_procedures', 'num_medications',
#        'number_outpatient', 'number_emergency', 'number_inpatient', 'diag_1',
#        'diag_2', 'diag_3', 'number_diagnoses', 'max_glu_serum', 'A1Cresult',
#        'metformin', 'repaglinide', 'nateglinide', 'chlorpropamide',
#        'glimepiride', 'acetohexamide', 'glipizide', 'glyburide', 'tolbutamide',
#        'pioglitazone', 'rosiglitazone', 'acarbose', 'miglitol', 'troglitazone',
#        'tolazamide', 'insulin', 'glyburide-metformin', 'glipizide-metformin',
#        'glimepiride-pioglitazone', 'metformin-rosiglitazone',
#        'metformin-pioglitazone', 'change', 'diabetesMed', 'readmitted'],
#       dtype='object')

# %%
pipe = Pipeline(steps=[("scale", StandardScaler()), 
                       ("model", LogisticRegression())])

# %%
train_2 = train.copy()
train_2.dropna(subset = 'race')
results = cross_validate(estimator=pipe, 
                X=train_2.drop(columns="race"), 
                y=train_2["race"], 
                cv=5, 
                         return_estimator=True,
                scoring="accuracy")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/joaquindominguez/Box/SMU/QuantTheWorld/case_studies/QTW_CaseStudy/Case Study 2/JD_draft.ipynb Cell 45 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/Users/joaquindominguez/Box/SMU/QuantTheWorld/case_studies/QTW_CaseStudy/Case%20Study%202/JD_draft.ipynb#Y141sZmlsZQ%3D%3D?line=0'>1</a> train_2 = train.copy()
#       <a href='vscode-notebook-cell:/Users/joaquindominguez/Box/SMU/QuantTheWorld/case_studies/QTW_CaseStudy/Case%20Study%202/JD_draft.ipynb#Y141sZmlsZQ%3D%3D?line=1'>2</a> train_2.dropna(subset = 'race')
# ----> <a href='vscode-notebook-cell:/Users/joaquindominguez/Box/SMU/QuantTheWorld/case_studies/QTW_CaseStudy/Case%20Study%202/JD_draft.ipynb#Y141sZmlsZQ%3D%3D?line=2'>3</a> results = cross_validate(estimator=pipe,
#       <a href='vscode-notebook-cell:/Users/joaquindominguez/Box/SMU/QuantTheWorld/case_studies/QTW_CaseStudy/Case%20Study%202/JD_draft.ipynb#Y141sZmlsZQ%3D%3D?line=3'>4</a>                 X=train_2.drop(columns="race"),
#       <a href='vscode-notebook-cell:/Users/joaquindominguez/Box/SMU/QuantTheWorld/case_studies/QTW_CaseStudy/Case%20Study%202/JD_draft.ipynb#Y141sZmlsZQ%3D%3D?line=4'>5</a>                 y=train_2["race"],
#       <a href='vscode-notebook-cell:/Users/joaquindominguez/Box/SMU/QuantTheWorld/case_studies/QTW_CaseStudy/Case%20Study%202/JD_draft.ipynb#Y141sZmlsZQ%3D%3D?line=5'>6</a>                 cv=5,
#       <a href='vscode-notebook-cell:/Users/joaquindominguez/Box/SMU/QuantTheWorld/case_studies/QTW_CaseStudy/Case%20Study%202/JD_draft.ipynb#Y141sZmlsZQ%3D%3D?line=6'>7</a>                          return_estimator=True,
#       <a href='vscode-notebook-cell:/Users/joaquindominguez/Box/SMU/QuantTheWorld/case_studies/QTW_CaseStudy/Case%20Study%202/JD_draft.ipynb#Y141sZmlsZQ%3D%3D?line=7'>8</a>                 scoring="accuracy")
#
# File /usr/local/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:254, in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, return_train_score, return_estimator, error_score)
#      65 """Evaluate metric(s) by cross-validation and also record fit/score times.
#      66
#      67 Read more in the :ref:`User Guide <multimetric_cross_validation>`.
#    (...)
#     250 [0.28009951 0.3908844  0.22784907]
#     251 """
#     252 X, y, groups = indexable(X, y, groups)
# --> 254 cv = check_cv(cv, y, classifier=is_classifier(estimator))
#     256 if callable(scoring):
#     257     scorers = scoring
#
# File /usr/local/lib/python3.10/site-packages/sklearn/model_selection/_split.py:2331, in check_cv(cv, y, classifier)
#    2326 cv = 5 if cv is None else cv
#    2327 if isinstance(cv, numbers.Integral):
#    2328     if (
#    2329         classifier
#    2330         and (y is not None)
# -> 2331         and (type_of_target(y, input_name="y") in ("binary", "multiclass"))
#    2332     ):
#    2333         return StratifiedKFold(cv)
#    2334     else:
#
# File /usr/local/lib/python3.10/site-packages/sklearn/utils/multiclass.py:335, in type_of_target(y, input_name)
#     332     _assert_all_finite(y, input_name=input_name)
#     333     return "continuous" + suffix
# --> 335 if (len(np.unique(y)) > 2) or (y.ndim >= 2 and len(y[0]) > 1):
#     336     return "multiclass" + suffix  # [1, 2, 3] or [[1., 2., 3]] or [[1, 2]]
#     337 else:
#
# File <__array_function__ internals>:180, in unique(*args, **kwargs)
#
# File /usr/local/lib/python3.10/site-packages/numpy/lib/arraysetops.py:274, in unique(ar, return_index, return_inverse, return_counts, axis, equal_nan)
#     272 ar = np.asanyarray(ar)
#     273 if axis is None:
# --> 274     ret = _unique1d(ar, return_index, return_inverse, return_counts,
#     275                     equal_nan=equal_nan)
#     276     return _unpack_tuple(ret)
#     278 # axis was specified and not None
#
# File /usr/local/lib/python3.10/site-packages/numpy/lib/arraysetops.py:336, in _unique1d(ar, return_index, return_inverse, return_counts, equal_nan)
#     334     aux = ar[perm]
#     335 else:
# --> 336     ar.sort()
#     337     aux = ar
#     338 mask = np.empty(aux.shape, dtype=np.bool_)
#
# TypeError: '<' not supported between instances of 'float' and 'str'

# %%
train.loc[train['race'].isna(), 'race']
# Out:
# 12913    NaN
# 21377    NaN
# 83119    NaN
# 31981    NaN
# 30343    NaN
#         ...
# 98018    NaN
# 77373    NaN
# 2568     NaN
# 35773    NaN
# 16023    NaN
# Name: race, Length: 1824, dtype: object
